# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd ../
# Out:
# /Users/anar/Desktop/tum/OctaPose

# %%
from src.datasets.pose_triplet_dataset import PoseTripletDataset, collate_triplets
from src.models.pose_encoder import PoseGRUHybrid
from src.training.train import train_model

import pyarrow.parquet as pq
from torch.utils.data import DataLoader
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
table = pq.read_table("data/poses/all_fighters.parquet")
dataset = PoseTripletDataset(table)
loader = DataLoader(dataset, batch_size=16, shuffle=False, collate_fn=collate_triplets)
model = PoseGRUHybrid(3)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
train_model(model, loader, optimizer, epoch=30)
# Out:
# Epoch 1: 100%|██████████| 1/1 [00:02<00:00,  2.12s/it]
# Epoch 1 | Loss: 1.1317 | Acc: 20.00%
# Epoch 2: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Epoch 2 | Loss: 1.0917 | Acc: 33.33%
# Epoch 3: 100%|██████████| 1/1 [00:01<00:00,  1.33s/it]
# Epoch 3 | Loss: 1.0929 | Acc: 46.67%
# Epoch 4: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Epoch 4 | Loss: 1.0858 | Acc: 20.00%
# Epoch 5: 100%|██████████| 1/1 [00:02<00:00,  2.01s/it]
# Epoch 5 | Loss: 1.0728 | Acc: 13.33%
# Epoch 6: 100%|██████████| 1/1 [00:01<00:00,  1.99s/it]
# Epoch 6 | Loss: 1.1008 | Acc: 6.67%
# Epoch 7: 100%|██████████| 1/1 [00:02<00:00,  2.08s/it]
# Epoch 7 | Loss: 1.0952 | Acc: 53.33%
# Epoch 8: 100%|██████████| 1/1 [00:02<00:00,  2.65s/it]
# Epoch 8 | Loss: 1.1010 | Acc: 26.67%
# Epoch 9: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it]
# Epoch 9 | Loss: 1.0642 | Acc: 53.33%
# Epoch 10: 100%|██████████| 1/1 [00:02<00:00,  2.39s/it]
# Epoch 10 | Loss: 1.0600 | Acc: 33.33%
# Epoch 11: 100%|██████████| 1/1 [00:02<00:00,  2.32s/it]
# Epoch 11 | Loss: 1.0609 | Acc: 33.33%
# Epoch 12: 100%|██████████| 1/1 [00:02<00:00,  2.06s/it]
# Epoch 12 | Loss: 1.0646 | Acc: 46.67%
# Epoch 13: 100%|██████████| 1/1 [00:01<00:00,  1.92s/it]
# Epoch 13 | Loss: 1.0703 | Acc: 26.67%
# Epoch 14: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Epoch 14 | Loss: 1.0583 | Acc: 53.33%
# Epoch 15: 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# Epoch 15 | Loss: 1.0459 | Acc: 60.00%
# Epoch 16: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Epoch 16 | Loss: 1.0682 | Acc: 33.33%
# Epoch 17: 100%|██████████| 1/1 [00:01<00:00,  1.85s/it]
# Epoch 17 | Loss: 1.0473 | Acc: 40.00%
# Epoch 18: 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
# Epoch 18 | Loss: 1.0555 | Acc: 46.67%
# Epoch 19: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]
# Epoch 19 | Loss: 1.0720 | Acc: 40.00%
# Epoch 20: 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
# Epoch 20 | Loss: 1.0483 | Acc: 13.33%
# Epoch 21: 100%|██████████| 1/1 [00:02<00:00,  2.13s/it]
# Epoch 21 | Loss: 1.0691 | Acc: 53.33%
# Epoch 22: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Epoch 22 | Loss: 1.0492 | Acc: 46.67%
# Epoch 23: 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# Epoch 23 | Loss: 1.0904 | Acc: 13.33%
# Epoch 24: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# Epoch 24 | Loss: 1.0256 | Acc: 60.00%
# Epoch 25: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Epoch 25 | Loss: 1.0275 | Acc: 46.67%
# Epoch 26: 100%|██████████| 1/1 [00:01<00:00,  1.80s/it]
# Epoch 26 | Loss: 1.0470 | Acc: 20.00%
# Epoch 27: 100%|██████████| 1/1 [00:01<00:00,  1.97s/it]
# Epoch 27 | Loss: 1.0330 | Acc: 53.33%
# Epoch 28: 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# Epoch 28 | Loss: 1.0619 | Acc: 40.00%
# Epoch 29: 100%|██████████| 1/1 [00:01<00:00,  1.83s/it]
# Epoch 29 | Loss: 1.0340 | Acc: 53.33%
# Epoch 30: 100%|██████████| 1/1 [00:01<00:00,  1.81s/it]
# Epoch 30 | Loss: 1.0420 | Acc: 40.00%

# %%
all_embeddings = []
labels = []

with torch.no_grad():
    for item in dataset.data:
        pose = item["pose"].unsqueeze(0)  # (1, T, 17, 2)
        length = torch.tensor([item["length"]])
        emb, _ = model(pose, length)  # (1, D)
        all_embeddings.append(emb.squeeze(0).numpy())
        labels.append(item["fighter"])  # fighter name

embeddings = np.stack(all_embeddings)

# %%
embeddings.shape
# Out:
# (15, 64)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

unique_labels = list(set(labels))
colors = plt.cm.get_cmap("tab10", len(unique_labels))

for i, label in enumerate(unique_labels):
    idxs = [j for j, l in enumerate(labels) if l == label]
    ax.scatter(*embeddings[idxs].T, label=label, color=colors(i), alpha=0.8, s=60)

ax.set_title("3D Embedding Space by Fighter")
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m6/40k0v17n0xn74zsggnhf227w0000gn/T/ipykernel_46077/2555137688.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab10", len(unique_labels))
